# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 531s 3us/step
# 170508288/170498071 [==============================] - 531s 3us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(250, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 64)          16448
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 4, 4, 64)          16448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 500)               128500
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 175,078
# Trainable params: 175,078
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 73s - loss: 1.7898 - acc: 0.3344 - val_loss: 1.9024 - val_acc: 0.3356
#
# Epoch 00001: val_loss improved from inf to 1.90239, saving model to model.weights.best.hdf5
# Epoch 2/20
#  - 63s - loss: 1.4854 - acc: 0.4552 - val_loss: 1.4965 - val_acc: 0.4796
#
# Epoch 00002: val_loss improved from 1.90239 to 1.49650, saving model to model.weights.best.hdf5
# Epoch 3/20
#  - 66s - loss: 1.3709 - acc: 0.5030 - val_loss: 1.3053 - val_acc: 0.5270
#
# Epoch 00003: val_loss improved from 1.49650 to 1.30533, saving model to model.weights.best.hdf5
# Epoch 4/20
#  - 60s - loss: 1.2947 - acc: 0.5336 - val_loss: 1.5267 - val_acc: 0.4544
#
# Epoch 00004: val_loss did not improve from 1.30533
# Epoch 5/20
#  - 67s - loss: 1.2536 - acc: 0.5513 - val_loss: 1.2774 - val_acc: 0.5642
#
# Epoch 00005: val_loss improved from 1.30533 to 1.27743, saving model to model.weights.best.hdf5
# Epoch 6/20
#  - 68s - loss: 1.2297 - acc: 0.5630 - val_loss: 1.1741 - val_acc: 0.5994
#
# Epoch 00006: val_loss improved from 1.27743 to 1.17414, saving model to model.weights.best.hdf5
# Epoch 7/20
#  - 67s - loss: 1.2140 - acc: 0.5728 - val_loss: 1.2175 - val_acc: 0.5490
#
# Epoch 00007: val_loss did not improve from 1.17414
# Epoch 8/20
#  - 69s - loss: 1.2140 - acc: 0.5784 - val_loss: 1.2146 - val_acc: 0.5594
#
# Epoch 00008: val_loss did not improve from 1.17414
# Epoch 9/20
#  - 59s - loss: 1.2123 - acc: 0.5788 - val_loss: 1.1807 - val_acc: 0.6248
#
# Epoch 00009: val_loss did not improve from 1.17414
# Epoch 10/20
#  - 61s - loss: 1.2238 - acc: 0.5777 - val_loss: 1.2852 - val_acc: 0.5280
#
# Epoch 00010: val_loss did not improve from 1.17414
# Epoch 11/20
#  - 55s - loss: 1.2304 - acc: 0.5769 - val_loss: 1.1436 - val_acc: 0.6104
#
# Epoch 00011: val_loss improved from 1.17414 to 1.14361, saving model to model.weights.best.hdf5
# Epoch 12/20
#  - 55s - loss: 1.2389 - acc: 0.5729 - val_loss: 1.1982 - val_acc: 0.5904
#
# Epoch 00012: val_loss did not improve from 1.14361
# Epoch 13/20
#  - 55s - loss: 1.2469 - acc: 0.5683 - val_loss: 1.0716 - val_acc: 0.6242
#
# Epoch 00013: val_loss improved from 1.14361 to 1.07164, saving model to model.weights.best.hdf5
# Epoch 14/20
#  - 56s - loss: 1.2623 - acc: 0.5653 - val_loss: 1.2472 - val_acc: 0.5814
#
# Epoch 00014: val_loss did not improve from 1.07164
# Epoch 15/20
#  - 56s - loss: 1.2919 - acc: 0.5583 - val_loss: 1.1455 - val_acc: 0.6056
#
# Epoch 00015: val_loss did not improve from 1.07164
# Epoch 16/20
#  - 55s - loss: 1.3093 - acc: 0.5533 - val_loss: 1.1355 - val_acc: 0.6062
#
# Epoch 00016: val_loss did not improve from 1.07164
# Epoch 17/20
#  - 57s - loss: 1.3302 - acc: 0.5465 - val_loss: 1.4350 - val_acc: 0.5304
#
# Epoch 00017: val_loss did not improve from 1.07164
# Epoch 18/20
#  - 62s - loss: 1.3511 - acc: 0.5393 - val_loss: 1.2202 - val_acc: 0.5958
#
# Epoch 00018: val_loss did not improve from 1.07164
# Epoch 19/20
#  - 77s - loss: 1.3700 - acc: 0.5316 - val_loss: 1.3419 - val_acc: 0.5438
#
# Epoch 00019: val_loss did not improve from 1.07164
# Epoch 20/20
#  - 75s - loss: 1.4008 - acc: 0.5206 - val_loss: 1.2719 - val_acc: 0.5388
#
# Epoch 00020: val_loss did not improve from 1.07164

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.6165)

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
